# %%
myList = [10,20,30,40]

# %%
type (myList)
# Out:
# list

# %%
type (myList[2])
# Out:
# int

# %%
myList [2]
# Out:
# 30

# %%
len (myList)
# Out:
# 4

# %%
myList.append(224)

# %%
myList
# Out:
# [10, 20, 30, 40, 224]

# %%
myList.count (40)
# Out:
# 1

# %%
x = input ( "enter x " )
# Out:
# enter x  20

# %%
x
# Out:
# '20'

# %%
type (x)
# Out:
# str

# %%
y = input ("enter y : ")
# Out:
# enter y :  41

# %%
y
# Out:
# '41'
