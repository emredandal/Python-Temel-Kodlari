# %%
age = input("enter age: ")
# Out:
# enter age:  19

# %%
age
# Out:
# '19'

# %%
int(age) * 2
# Out:
# 38

# %%
while True:
    try:
        myAge = int(input("enter age: "))
        print(myAge * 2)
        #break
    except:
        print("enter your age!!!")
    else:
        print("else executed")
        break
    finally:
        print("finally")
# Out:
# enter age:  ne
# enter your age!!!
# finally
# enter age:  olmaz
# enter your age!!!
# finally
# enter age:  emre
# enter your age!!!
# finally
# enter age:  19
# 38
# else executed
# finally
