# %%
age = 50

# %%
age
# Out:
# 50

# %%
age * 5
# Out:
# 250

# %%
age
# Out:
# 50

# %%
age ** 5
# Out:
# 312500000

# %%
#data type

# %%
type (10)
# Out:
# int

# %%
type (1.2)
# Out:
# float

# %%
type (-100)
# Out:
# int

# %%
x = -10

# %%
type (x)
# Out:
# int

# %%
y = 21

# %%
type (y)
# Out:
# int

# %%
pi = 3.14

# %%
pi
# Out:
# 3.14

# %%
x
# Out:
# -10

# %%
pi - x
# Out:
# 13.14

# %%
my_Float = 2.414241

# %%
type (my_Float)
# Out:
# float

# %%
#camelCase
#snake_case denir

# %%
10 ** 2
# Out:
# 100

# %%
10 % 3
# Out:
# 1

# %%
10 % 4
# Out:
# 2
