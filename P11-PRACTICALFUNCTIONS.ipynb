# %%
help(map)
# Out:
# Help on class map in module builtins:
#
# class map(object)
#  |  map(function, iterable, /, *iterables)
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(self, /)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
def controlString(string):
    return "emre" in string

# %%
controlString("emre dandal")
# Out:
# True

# %%
myStringList = ["emre", "emre dandal","dandal","emre"]

# %%
list(map(controlString,myStringList))
# Out:
# [True, True, False, True]

# %%
list(filter(controlString,myStringList))
# Out:
# ['emre', 'emre dandal', 'emre']

# %%
multiplyLambda = lambda num : num * 3

# %%
type(multiplyLambda)
# Out:
# function

# %%
multiplyLambda(20)
# Out:
# 60

# %%
result = multiplyLambda(10)

# %%
result
# Out:
# 30

# %%
x = 20

def multiply(num):
    x = 5
    return num * x

# %%
multiply(10)
# Out:
# 50

# %%
print(x)
# Out:
# 20

# %%
a = 10

# %%
a
# Out:
# 10

# %%
#Global
myString = "emre"

def myFunction():
    #Enclosing
    myString = "emre 2"
    print(myString)
    
    def myFunction2():
        #Local
        myString = "emre 3"
        print(myString)
    
    myFunction2()

# %%
myString
# Out:
# 'emre'

# %%
myFunction()
# Out:
# emre 2
# emre 3

# %%
myString
# Out:
# 'emre'

# %%
def test1():
    myX= 10
    print(myX * 2)

def test2():
    print(myX * 3)

# %%
test1()
# Out:
# 20

# %%
y = 10
def newFunction(y):
    print(y)
    y = 5
    print(y)
    return y

# %%
newFunction(10)
# Out:
# 10
# 5
# 5
