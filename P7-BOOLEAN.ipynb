# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
kararlarim = True

# %%
type(kararlarim)
# Out:
# bool

# %%
5 > 3
# Out:
# True

# %%
2 < 1
# Out:
# False

# %%
age = input("enter age: ")
# Out:
# enter age:  19

# %%
age
# Out:
# '19'

# %%
int(age) > 18
# Out:
# True
