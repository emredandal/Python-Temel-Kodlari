# %%
#MyTuple tanımladıktan sonra hıc bır sekılde degıstırılemez.

# %%
myList = [10,"a","b",3.14]

# %%
myList[0]
# Out:
# 10

# %%
myList[0] = 100

# %%
myList
# Out:
# [100, 'a', 'b', 3.14]

# %%
myTuple = (10,"a","b",3.14)

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[0]
# Out:
# 10

# %%
myTuple[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 myTuple[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
#goruldugu uzere hata verıyor yanı bır sey eklenemedı
